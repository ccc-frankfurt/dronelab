# %%
import math
from pathlib import Path
import subprocess
import shutil


in_data = "/projects/sysl2/rail_novelity_training/gen_data/handpicked_rails"
out = "/projects/sysl2/rail_novelity_training/gen_data/data"

# %%
for path in Path(in_data).resolve().rglob('*.json'):
    stem = path.stem
    out_path = path.with_name(stem+"_mask")
    subprocess.run(["labelme_json_to_dataset", str(path), "-o", str(out_path)])

# %%
Path(out).mkdir(parents=True, exist_ok=True)
for path in Path(in_data).iterdir():
    if path.is_dir():
        (Path(out)/path.stem).mkdir(parents=True, exist_ok=True)

# %%
out_path = Path(out)
for path in Path(in_data).rglob('label.png'):
    out_img = )/(path.parent.parent)/(path.parent.stem+".png")
    #shutil.copyfile(path, out_img)
    
    print(path)
    print(Path(out)/(path.parent.parent))
    #subprocess.run(["labelme_json_to_dataset", str(path), "-o", str(out_path)])
# Out:
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15\fps_1_frame_011_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15\fps_1_frame_012_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15\fps_1_frame_013_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15\fps_1_frame_014_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15\fps_1_frame_015_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15\fps_1_frame_016_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15\fps_1_frame_017_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15\fps_1_frame_018_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15\fps_1_frame_019_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15\fps_1_frame_025_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15\fps_1_frame_026_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15\fps_1_frame_027_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15\fps_1_frame_028_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15\fps_1_frame_029_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15\fps_1_frame_030_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15\fps_1_frame_031_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15\fps_1_frame_032_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15\fps_1_frame_033_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15\fps_1_frame_034_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-14-51-15
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_004_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_005_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_006_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_007_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_008_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_009_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_010_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_011_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_012_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_013_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_014_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_015_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_033_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_034_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_035_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_036_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_037_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_038_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_039_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_040_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_041_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00\fps_1_frame_042_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-04-00
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-07-48\fps_1_frame_017_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-07-48
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-07-48\fps_1_frame_018_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-07-48
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-07-48\fps_1_frame_019_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-07-48
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-07-48\fps_1_frame_020_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-07-48
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-07-48\fps_1_frame_021_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-07-48
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-07-48\fps_1_frame_022_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-07-48
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-07-48\fps_1_frame_023_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-07-48
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-07-48\fps_1_frame_024_mask\label.png
# \projects\sysl2\rail_novelity_training\gen_data\handpicked_rails\2021-07-01-17-07-48
